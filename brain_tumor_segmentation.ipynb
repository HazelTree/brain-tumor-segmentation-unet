# %%
# !pip install hdf5storage
# !git clone https://github.com/adityajn105/brain-tumor-segmentation-unet
# !bash download_data.sh
# !python mat_to_numpy.py brain_tumor_dataset/
# Out:
# download_data.sh: line 7: wget: command not found
# unzip:  cannot find or open temp.zip, temp.zip.zip or temp.zip.ZIP.
# cat: brainTumorDataPublic_*: No such file or directory
# unzip:  cannot find or open brainTumorDataPublic_temp.zip, brainTumorDataPublic_temp.zip.zip or brainTumorDataPublic_temp.zip.ZIP.
# ls: data: No such file or directory
#        0
# Traceback (most recent call last):
#   File "mat_to_numpy.py", line 14, in <module>
#     import cv2
# ModuleNotFoundError: No module named 'cv2'

# %%
# !python mat_to_numpy.py brain_tumor_dataset/
# Out:
# Traceback (most recent call last):
#   File "mat_to_numpy.py", line 14, in <module>
#     import cv2
# ModuleNotFoundError: No module named 'cv2'

# %%
# !pip install hdf5storage
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting hdf5storage
#   Downloading hdf5storage-0.1.15-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 1.9 MB/s eta 0:00:01
# Requirement already satisfied: numpy; python_version >= "3.4" in /opt/conda/lib/python3.7/site-packages (from hdf5storage) (1.18.1)
# Requirement already satisfied: h5py>=2.1; python_version >= "3.3" in /opt/conda/lib/python3.7/site-packages (from hdf5storage) (2.9.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from h5py>=2.1; python_version >= "3.3"->hdf5storage) (1.12.0)
# Installing collected packages: hdf5storage
# Successfully installed hdf5storage-0.1.15

# %%
# !python mat_to_numpy.py brain_tumor_dataset/
# Out:
# [3064/3064] images loaded: 100.0 %
# labels: (3064,)
# images: (3064, 512, 512)
# masks: (3064, 512, 512)
# labels.npy, images.npy, masks.npy saved in brain_tumor_dataset/

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

integer_to_class = {'1': 'meningioma (1)', '2': 'glioma (2)', '3': 'pituitary tumor (3)'}

##Load images, labels, masks
labels = np.load('brain_tumor_dataset/labels.npy')
images = np.clip( (np.load('brain_tumor_dataset/images.npy')/12728),0,1)
masks = np.load('brain_tumor_dataset/masks.npy')*1
print(labels.shape)
print(images.shape)
print(masks.shape)
# Out:
# (3064,)
# (3064, 512, 512)
# (3064, 512, 512)

# %%
from skimage.transform import resize
img_size_ori = 512
img_size_target = 128

images = np.expand_dims(images,axis=-1)
masks = np.expand_dims(masks,axis=-1)

def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True,)
    
def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)
  
images = np.array([ downsample(image) for image in images ])
masks = (np.array([ downsample(mask) for mask in masks ])>0)*1

print(images.shape)
print(masks.shape)
# Out:
# (3064, 128, 128, 1)
# (3064, 128, 128, 1)

# %%
classes, counts = np.unique(labels,return_counts=True)
plt.bar(classes,counts,tick_label=list(integer_to_class.values()))
print(counts)
# Out:
# [ 708 1426  930]

# %%
plt.figure(figsize=(12, 5))
for i, idx in enumerate(np.random.randint(images.shape[0], size=18), start=1):
    plt.subplot(3, 6, i)
    plt.imshow( np.squeeze(images[idx],axis=-1), cmap='gray')
    plt.imshow( np.squeeze(np.ones_like(masks[idx])-masks[idx],axis=-1), alpha=0.5, cmap='Set1')
    plt.title(integer_to_class[str(labels[idx])])
    plt.axis('off')

# %% [markdown]
# ### Train Image and its mask which is to be predicted

# %%
plt.figure(figsize=(12, 5))
i=1
for idx in np.random.randint( images.shape[0], size=9):
  plt.subplot(3,6,i);i+=1
  plt.imshow( np.squeeze(images[idx],axis=-1))
  plt.title("Train Image")
  plt.axis('off')
  plt.subplot(3,6,i);i+=1
  plt.imshow( np.squeeze(masks[idx],axis=-1)) 
  plt.title("Train Mask")
  plt.axis('off')

# %%
from sklearn.model_selection import train_test_split
import gc
X,X_v,Y,Y_v = train_test_split( images,masks,test_size=0.2,stratify=labels)
del images
del masks
del labels
gc.collect()
X.shape,X_v.shape
# Out:
# ((2451, 128, 128, 1), (613, 128, 128, 1))

# %% [markdown]
# ### Augmentation

# %%
# !pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting keras
#   Downloading Keras-2.3.1-py2.py3-none-any.whl (377 kB)
#      |████████████████████████████████| 377 kB 7.4 MB/s eta 0:00:01
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from keras) (5.1.2)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras) (2.9.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.7/site-packages (from keras) (1.18.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.7/site-packages (from keras) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/lib/python3.7/site-packages (from keras) (1.0.8)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.7/site-packages (from keras) (1.12.0)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.7/site-packages (from keras) (1.3.1)
# Installing collected packages: keras
# Successfully installed keras-2.3.1

# %%
X = np.append( X, [ np.fliplr(x) for x in X], axis=0 )
Y = np.append( Y, [ np.fliplr(y) for y in Y], axis=0 )
X.shape,Y.shape
# Out:
# ((4902, 128, 128, 1), (4902, 128, 128, 1))

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(brightness_range=(0.9,1.1),
                                   zoom_range=[.9,1.1],
                                   fill_mode='nearest')
val_datagen = ImageDataGenerator()
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ### Defining Dice Loss
# Dice = 2|A∩B|/|A|+|B|

# %%
from keras.losses import binary_crossentropy
from keras import backend as K
import tensorflow as tf

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

### bce_dice_loss = binary_crossentropy_loss + dice_loss
def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
from keras.layers import Conv2D, MaxPooling2D, Conv2DTranspose, concatenate, Dropout, Input, BatchNormalization
from keras import optimizers
from keras.models import Model

IMG_DIM = (128,128,1)

def conv2d_block( input_tensor, n_filters, kernel_size = (3,3), name="contraction"):
  "Add 2 conv layer"
  x = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer='he_normal', 
             padding='same',activation="relu", name=name+'_1')(input_tensor)
  
  x = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer='he_normal', 
             padding='same',activation="relu",name=name+'_2')(x)
  return x
  

inp = Input( shape=IMG_DIM )

d1 = conv2d_block( inp, 64, name="contraction_1")
p1 = MaxPooling2D( pool_size=(2,2), strides=(2,2))(d1)
p1 = BatchNormalization(momentum=0.8)(p1)
p1 = Dropout(0.1)(p1)

d2 = conv2d_block( p1, 128, name="contraction_2_1" )
p2 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d2)
p2 = BatchNormalization(momentum=0.8)(p2)
p2 = Dropout(0.1)(p2)

d3 = conv2d_block( p2, 256, name="contraction_3_1")
p3 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d3)
p3 = BatchNormalization(momentum=0.8)(p3)
p3 = Dropout(0.1)(p3)

d4 = conv2d_block(p3,512, name="contraction_4_1")
p4 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d4)
p4 = BatchNormalization(momentum=0.8)(p4)
p4 = Dropout(0.1)(p4)

d5 = conv2d_block(p4,512, name="contraction_5_1")

u1 = Conv2DTranspose(512, (3, 3), strides = (2, 2), padding = 'same')(d5)
u1 = concatenate([u1,d4])
u1 = Dropout(0.1)(u1)
c1 = conv2d_block(u1, 512, name="expansion_1")

u2 = Conv2DTranspose(256, (3, 3), strides = (2, 2), padding = 'same')(c1)
u2 = concatenate([u2,d3])
u2 = Dropout(0.1)(u2)
c2 = conv2d_block(u2, 256, name="expansion_2")

u3 = Conv2DTranspose(128, (3, 3), strides = (2, 2), padding = 'same')(c2)
u3 = concatenate([u3,d2])
u3 = Dropout(0.1)(u3)
c3 = conv2d_block(u3, 128, name="expansion_3")

u4 = Conv2DTranspose(64, (3, 3), strides = (2, 2), padding = 'same')(c3)
u4 = concatenate([u4,d1])
u4 = Dropout(0.1)(u4)
c4 = conv2d_block(u4,64, name="expansion_4")

out = Conv2D(1, (1,1), name="output", activation='sigmoid')(c4)

unet = Model( inp, out )
unet.summary()
# Out:
# WARNING:tensorflow:From /home/c3zhou/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# contraction_1_1 (Conv2D)        (None, 128, 128, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# contraction_1_2 (Conv2D)        (None, 128, 128, 64) 36928       contraction_1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)   0           contraction_1_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 64)   256         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# contraction_2_1_1 (Conv2D)      (None, 64, 64, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# contraction_2_1_2 (Conv2D)      (None, 64, 64, 128)  147584      contraction_2_1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0           contraction_2_1_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 128)  512         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# contraction_3_1_1 (Conv2D)      (None, 32, 32, 256)  295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# contraction_3_1_2 (Conv2D)      (None, 32, 32, 256)  590080      contraction_3_1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0           contraction_3_1_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 256)  1024        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# contraction_4_1_1 (Conv2D)      (None, 16, 16, 512)  1180160     dropout_3[0][0]
# __________________________________________________________________________________________________
# contraction_4_1_2 (Conv2D)      (None, 16, 16, 512)  2359808     contraction_4_1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 512)    0           contraction_4_1_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 512)    2048        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 512)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# contraction_5_1_1 (Conv2D)      (None, 8, 8, 512)    2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# contraction_5_1_2 (Conv2D)      (None, 8, 8, 512)    2359808     contraction_5_1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 512)  2359808     contraction_5_1_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 1024) 0           conv2d_transpose_1[0][0]
#                                                                  contraction_4_1_2[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 1024) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# expansion_1_1 (Conv2D)          (None, 16, 16, 512)  4719104     dropout_5[0][0]
# __________________________________________________________________________________________________
# expansion_1_2 (Conv2D)          (None, 16, 16, 512)  2359808     expansion_1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 256)  1179904     expansion_1_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 512)  0           conv2d_transpose_2[0][0]
#                                                                  contraction_3_1_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 512)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# expansion_2_1 (Conv2D)          (None, 32, 32, 256)  1179904     dropout_6[0][0]
# __________________________________________________________________________________________________
# expansion_2_2 (Conv2D)          (None, 32, 32, 256)  590080      expansion_2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 128)  295040      expansion_2_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_3[0][0]
#                                                                  contraction_2_1_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 256)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# expansion_3_1 (Conv2D)          (None, 64, 64, 128)  295040      dropout_7[0][0]
# __________________________________________________________________________________________________
# expansion_3_2 (Conv2D)          (None, 64, 64, 128)  147584      expansion_3_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 64) 73792       expansion_3_2[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_4[0][0]
#                                                                  contraction_1_2[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128, 128 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# expansion_4_1 (Conv2D)          (None, 128, 128, 64) 73792       dropout_8[0][0]
# __________________________________________________________________________________________________
# expansion_4_2 (Conv2D)          (None, 128, 128, 64) 36928       expansion_4_1[0][0]
# __________________________________________________________________________________________________
# output (Conv2D)                 (None, 128, 128, 1)  65          expansion_4_2[0][0]
# ==================================================================================================
# Total params: 22,718,529
# Trainable params: 22,716,609
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %% [markdown]
# ### Defining IOU metric and compile Model

# %%
def get_iou_vector(A, B):
    t = A>0
    p = B>0
    intersection = np.logical_and(t,p)
    union = np.logical_or(t,p)
    iou = (np.sum(intersection) + 1e-10 )/ (np.sum(union) + 1e-10)
    return iou

def iou_metric(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0.5], tf.float64)

unet.compile(optimizer=optimizers.Adam(lr=1e-3), 
             loss=bce_dice_loss, metrics=['accuracy',iou_metric])
# Out:
# WARNING:tensorflow:From <ipython-input-11-0b86264e04b1>:10: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import LabelEncoder
from keras.models import load_model

model_checkpoint  = ModelCheckpoint('model_best_checkpoint.h5', save_best_only=True, 
                                    monitor='val_loss', mode='min', verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')
reduceLR = ReduceLROnPlateau(patience=4, verbose=2, monitor='val_loss',min_lr=1e-4, mode='min')

callback_list = [early_stopping, reduceLR, model_checkpoint]

train_generator = train_datagen.flow(X, Y, batch_size=32)
val_generator = val_datagen.flow(X_v, Y_v, batch_size=32)

hist = unet.fit(X,Y,batch_size=32,epochs=100,
               validation_data=(X_v,Y_v),verbose=1,callbacks= callback_list)

unet = load_model('model_best_checkpoint.h5', custom_objects={'bce_dice_loss': bce_dice_loss,'iou_metric':iou_metric}) #or compile = False
# Out:
# WARNING:tensorflow:From /home/c3zhou/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 4902 samples, validate on 613 samples
# Epoch 1/100
# 4902/4902 [==============================] - 41s 8ms/step - loss: 0.9396 - accuracy: 0.9785 - iou_metric: 0.0748 - val_loss: 0.7609 - val_accuracy: 0.9812 - val_iou_metric: 0.1954
#
# Epoch 00001: val_loss improved from inf to 0.76090, saving model to model_best_checkpoint.h5
# Epoch 2/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.6540 - accuracy: 0.9873 - iou_metric: 0.2708 - val_loss: 0.5895 - val_accuracy: 0.9853 - val_iou_metric: 0.3239
#
# Epoch 00002: val_loss improved from 0.76090 to 0.58954, saving model to model_best_checkpoint.h5
# Epoch 3/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.4961 - accuracy: 0.9907 - iou_metric: 0.3964 - val_loss: 0.5680 - val_accuracy: 0.9922 - val_iou_metric: 0.3463
#
# Epoch 00003: val_loss improved from 0.58954 to 0.56804, saving model to model_best_checkpoint.h5
# Epoch 4/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.4224 - accuracy: 0.9922 - iou_metric: 0.4613 - val_loss: 0.3976 - val_accuracy: 0.9924 - val_iou_metric: 0.4935
#
# Epoch 00004: val_loss improved from 0.56804 to 0.39761, saving model to model_best_checkpoint.h5
# Epoch 5/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.3678 - accuracy: 0.9933 - iou_metric: 0.5139 - val_loss: 0.3901 - val_accuracy: 0.9924 - val_iou_metric: 0.4963
#
# Epoch 00005: val_loss improved from 0.39761 to 0.39014, saving model to model_best_checkpoint.h5
# Epoch 6/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.3565 - accuracy: 0.9934 - iou_metric: 0.5253 - val_loss: 0.3769 - val_accuracy: 0.9934 - val_iou_metric: 0.5074
#
# Epoch 00006: val_loss improved from 0.39014 to 0.37691, saving model to model_best_checkpoint.h5
# Epoch 7/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.3292 - accuracy: 0.9940 - iou_metric: 0.5540 - val_loss: 0.3845 - val_accuracy: 0.9939 - val_iou_metric: 0.5083
#
# Epoch 00007: val_loss did not improve from 0.37691
# Epoch 8/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.3180 - accuracy: 0.9941 - iou_metric: 0.5657 - val_loss: 0.4050 - val_accuracy: 0.9912 - val_iou_metric: 0.4821
#
# Epoch 00008: val_loss did not improve from 0.37691
# Epoch 9/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.2966 - accuracy: 0.9945 - iou_metric: 0.5888 - val_loss: 0.3035 - val_accuracy: 0.9946 - val_iou_metric: 0.5869
#
# Epoch 00009: val_loss improved from 0.37691 to 0.30352, saving model to model_best_checkpoint.h5
# Epoch 10/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.2854 - accuracy: 0.9947 - iou_metric: 0.6028 - val_loss: 0.3361 - val_accuracy: 0.9932 - val_iou_metric: 0.5532
#
# Epoch 00010: val_loss did not improve from 0.30352
# Epoch 11/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.2699 - accuracy: 0.9949 - iou_metric: 0.6190 - val_loss: 0.3425 - val_accuracy: 0.9941 - val_iou_metric: 0.5470
#
# Epoch 00011: val_loss did not improve from 0.30352
# Epoch 12/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.2484 - accuracy: 0.9954 - iou_metric: 0.6436 - val_loss: 0.3058 - val_accuracy: 0.9943 - val_iou_metric: 0.5808
#
# Epoch 00012: val_loss did not improve from 0.30352
# Epoch 13/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.2444 - accuracy: 0.9954 - iou_metric: 0.6466 - val_loss: 0.2985 - val_accuracy: 0.9939 - val_iou_metric: 0.5915
#
# Epoch 00013: val_loss improved from 0.30352 to 0.29848, saving model to model_best_checkpoint.h5
# Epoch 14/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.2418 - accuracy: 0.9955 - iou_metric: 0.6492 - val_loss: 0.2902 - val_accuracy: 0.9945 - val_iou_metric: 0.6015
#
# Epoch 00014: val_loss improved from 0.29848 to 0.29015, saving model to model_best_checkpoint.h5
# Epoch 15/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.2347 - accuracy: 0.9956 - iou_metric: 0.6593 - val_loss: 0.3003 - val_accuracy: 0.9944 - val_iou_metric: 0.5904
#
# Epoch 00015: val_loss did not improve from 0.29015
# Epoch 16/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.2330 - accuracy: 0.9956 - iou_metric: 0.6620 - val_loss: 0.2824 - val_accuracy: 0.9947 - val_iou_metric: 0.6090
#
# Epoch 00016: val_loss improved from 0.29015 to 0.28241, saving model to model_best_checkpoint.h5
# Epoch 17/100
# 4902/4902 [==============================] - 33s 7ms/step - loss: 0.2195 - accuracy: 0.9959 - iou_metric: 0.6778 - val_loss: 0.2782 - val_accuracy: 0.9949 - val_iou_metric: 0.6106
#
# Epoch 00017: val_loss improved from 0.28241 to 0.27818, saving model to model_best_checkpoint.h5
# Epoch 18/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.2121 - accuracy: 0.9960 - iou_metric: 0.6877 - val_loss: 0.2686 - val_accuracy: 0.9947 - val_iou_metric: 0.6204
#
# Epoch 00018: val_loss improved from 0.27818 to 0.26855, saving model to model_best_checkpoint.h5
# Epoch 19/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.2116 - accuracy: 0.9960 - iou_metric: 0.6879 - val_loss: 0.2859 - val_accuracy: 0.9943 - val_iou_metric: 0.6041
#
# Epoch 00019: val_loss did not improve from 0.26855
# Epoch 20/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1946 - accuracy: 0.9963 - iou_metric: 0.7084 - val_loss: 0.2735 - val_accuracy: 0.9947 - val_iou_metric: 0.6178
#
# Epoch 00020: val_loss did not improve from 0.26855
# Epoch 21/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1897 - accuracy: 0.9964 - iou_metric: 0.7157 - val_loss: 0.2691 - val_accuracy: 0.9951 - val_iou_metric: 0.6236
#
# Epoch 00021: val_loss did not improve from 0.26855
# Epoch 22/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1855 - accuracy: 0.9965 - iou_metric: 0.7184 - val_loss: 0.2596 - val_accuracy: 0.9951 - val_iou_metric: 0.6346
#
# Epoch 00022: val_loss improved from 0.26855 to 0.25958, saving model to model_best_checkpoint.h5
# Epoch 23/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1770 - accuracy: 0.9967 - iou_metric: 0.7321 - val_loss: 0.2739 - val_accuracy: 0.9951 - val_iou_metric: 0.6190
#
# Epoch 00023: val_loss did not improve from 0.25958
# Epoch 24/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1655 - accuracy: 0.9969 - iou_metric: 0.7469 - val_loss: 0.2597 - val_accuracy: 0.9951 - val_iou_metric: 0.6335
#
# Epoch 00024: val_loss did not improve from 0.25958
# Epoch 25/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1695 - accuracy: 0.9968 - iou_metric: 0.7421 - val_loss: 0.2776 - val_accuracy: 0.9945 - val_iou_metric: 0.6146
#
# Epoch 00025: val_loss did not improve from 0.25958
# Epoch 26/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1666 - accuracy: 0.9969 - iou_metric: 0.7461 - val_loss: 0.2819 - val_accuracy: 0.9945 - val_iou_metric: 0.6111
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00026: val_loss did not improve from 0.25958
# Epoch 27/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1428 - accuracy: 0.9973 - iou_metric: 0.7762 - val_loss: 0.2495 - val_accuracy: 0.9954 - val_iou_metric: 0.6448
#
# Epoch 00027: val_loss improved from 0.25958 to 0.24954, saving model to model_best_checkpoint.h5
# Epoch 28/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1340 - accuracy: 0.9975 - iou_metric: 0.7899 - val_loss: 0.2468 - val_accuracy: 0.9955 - val_iou_metric: 0.6487
#
# Epoch 00028: val_loss improved from 0.24954 to 0.24676, saving model to model_best_checkpoint.h5
# Epoch 29/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1304 - accuracy: 0.9975 - iou_metric: 0.7948 - val_loss: 0.2453 - val_accuracy: 0.9955 - val_iou_metric: 0.6499
#
# Epoch 00029: val_loss improved from 0.24676 to 0.24529, saving model to model_best_checkpoint.h5
# Epoch 30/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1268 - accuracy: 0.9976 - iou_metric: 0.7996 - val_loss: 0.2473 - val_accuracy: 0.9954 - val_iou_metric: 0.6479
#
# Epoch 00030: val_loss did not improve from 0.24529
# Epoch 31/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1249 - accuracy: 0.9976 - iou_metric: 0.8024 - val_loss: 0.2480 - val_accuracy: 0.9955 - val_iou_metric: 0.6481
#
# Epoch 00031: val_loss did not improve from 0.24529
# Epoch 32/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1225 - accuracy: 0.9977 - iou_metric: 0.8064 - val_loss: 0.2443 - val_accuracy: 0.9955 - val_iou_metric: 0.6524
#
# Epoch 00032: val_loss improved from 0.24529 to 0.24429, saving model to model_best_checkpoint.h5
# Epoch 33/100
# 4902/4902 [==============================] - 33s 7ms/step - loss: 0.1192 - accuracy: 0.9977 - iou_metric: 0.8112 - val_loss: 0.2448 - val_accuracy: 0.9955 - val_iou_metric: 0.6514
#
# Epoch 00033: val_loss did not improve from 0.24429
# Epoch 34/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1172 - accuracy: 0.9978 - iou_metric: 0.8130 - val_loss: 0.2513 - val_accuracy: 0.9954 - val_iou_metric: 0.6442
#
# Epoch 00034: val_loss did not improve from 0.24429
# Epoch 35/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1166 - accuracy: 0.9978 - iou_metric: 0.8148 - val_loss: 0.2477 - val_accuracy: 0.9955 - val_iou_metric: 0.6489
#
# Epoch 00035: val_loss did not improve from 0.24429
# Epoch 36/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1147 - accuracy: 0.9978 - iou_metric: 0.8177 - val_loss: 0.2453 - val_accuracy: 0.9955 - val_iou_metric: 0.6515
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00036: val_loss did not improve from 0.24429
# Epoch 37/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1121 - accuracy: 0.9979 - iou_metric: 0.8212 - val_loss: 0.2476 - val_accuracy: 0.9954 - val_iou_metric: 0.6491
#
# Epoch 00037: val_loss did not improve from 0.24429
# Epoch 38/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1108 - accuracy: 0.9979 - iou_metric: 0.8234 - val_loss: 0.2460 - val_accuracy: 0.9955 - val_iou_metric: 0.6509
#
# Epoch 00038: val_loss did not improve from 0.24429
# Epoch 39/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1084 - accuracy: 0.9980 - iou_metric: 0.8270 - val_loss: 0.2464 - val_accuracy: 0.9955 - val_iou_metric: 0.6508
#
# Epoch 00039: val_loss did not improve from 0.24429
# Epoch 40/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1068 - accuracy: 0.9980 - iou_metric: 0.8288 - val_loss: 0.2453 - val_accuracy: 0.9955 - val_iou_metric: 0.6526
#
# Epoch 00040: val_loss did not improve from 0.24429
# Epoch 41/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1054 - accuracy: 0.9980 - iou_metric: 0.8310 - val_loss: 0.2438 - val_accuracy: 0.9955 - val_iou_metric: 0.6531
#
# Epoch 00041: val_loss improved from 0.24429 to 0.24379, saving model to model_best_checkpoint.h5
# Epoch 42/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1040 - accuracy: 0.9980 - iou_metric: 0.8330 - val_loss: 0.2437 - val_accuracy: 0.9955 - val_iou_metric: 0.6541
#
# Epoch 00042: val_loss improved from 0.24379 to 0.24373, saving model to model_best_checkpoint.h5
# Epoch 43/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1025 - accuracy: 0.9981 - iou_metric: 0.8352 - val_loss: 0.2429 - val_accuracy: 0.9955 - val_iou_metric: 0.6548
#
# Epoch 00043: val_loss improved from 0.24373 to 0.24289, saving model to model_best_checkpoint.h5
# Epoch 44/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.1012 - accuracy: 0.9981 - iou_metric: 0.8375 - val_loss: 0.2418 - val_accuracy: 0.9956 - val_iou_metric: 0.6566
#
# Epoch 00044: val_loss improved from 0.24289 to 0.24184, saving model to model_best_checkpoint.h5
# Epoch 45/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.0997 - accuracy: 0.9981 - iou_metric: 0.8400 - val_loss: 0.2447 - val_accuracy: 0.9956 - val_iou_metric: 0.6527
#
# Epoch 00045: val_loss did not improve from 0.24184
# Epoch 46/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.0974 - accuracy: 0.9982 - iou_metric: 0.8430 - val_loss: 0.2402 - val_accuracy: 0.9956 - val_iou_metric: 0.6586
#
# Epoch 00046: val_loss improved from 0.24184 to 0.24017, saving model to model_best_checkpoint.h5
# Epoch 47/100
# 4902/4902 [==============================] - 33s 7ms/step - loss: 0.0951 - accuracy: 0.9982 - iou_metric: 0.8469 - val_loss: 0.2413 - val_accuracy: 0.9956 - val_iou_metric: 0.6588
#
# Epoch 00047: val_loss did not improve from 0.24017
# Epoch 48/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.0947 - accuracy: 0.9982 - iou_metric: 0.8475 - val_loss: 0.2411 - val_accuracy: 0.9956 - val_iou_metric: 0.6597
#
# Epoch 00048: val_loss did not improve from 0.24017
# Epoch 49/100
# 4902/4902 [==============================] - 33s 7ms/step - loss: 0.0929 - accuracy: 0.9982 - iou_metric: 0.8499 - val_loss: 0.2433 - val_accuracy: 0.9956 - val_iou_metric: 0.6564
#
# Epoch 00049: val_loss did not improve from 0.24017
# Epoch 50/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.0913 - accuracy: 0.9983 - iou_metric: 0.8521 - val_loss: 0.2422 - val_accuracy: 0.9956 - val_iou_metric: 0.6585
#
# Epoch 00050: val_loss did not improve from 0.24017
# Epoch 51/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.0904 - accuracy: 0.9983 - iou_metric: 0.8540 - val_loss: 0.2449 - val_accuracy: 0.9956 - val_iou_metric: 0.6555
#
# Epoch 00051: val_loss did not improve from 0.24017
# Epoch 52/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.0888 - accuracy: 0.9983 - iou_metric: 0.8564 - val_loss: 0.2422 - val_accuracy: 0.9956 - val_iou_metric: 0.6605
#
# Epoch 00052: val_loss did not improve from 0.24017
# Epoch 53/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.0874 - accuracy: 0.9983 - iou_metric: 0.8585 - val_loss: 0.2444 - val_accuracy: 0.9956 - val_iou_metric: 0.6559
#
# Epoch 00053: val_loss did not improve from 0.24017
# Epoch 54/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.0866 - accuracy: 0.9984 - iou_metric: 0.8594 - val_loss: 0.2434 - val_accuracy: 0.9956 - val_iou_metric: 0.6564
#
# Epoch 00054: val_loss did not improve from 0.24017
# Epoch 55/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.0860 - accuracy: 0.9984 - iou_metric: 0.8605 - val_loss: 0.2461 - val_accuracy: 0.9956 - val_iou_metric: 0.6535
#
# Epoch 00055: val_loss did not improve from 0.24017
# Epoch 56/100
# 4902/4902 [==============================] - 34s 7ms/step - loss: 0.0842 - accuracy: 0.9984 - iou_metric: 0.8625 - val_loss: 0.2442 - val_accuracy: 0.9956 - val_iou_metric: 0.6580
#
# Epoch 00056: val_loss did not improve from 0.24017

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 4))
t = f.suptitle('Unet Performance in Segmenting Tumors', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)
epoch_list = hist.epoch

ax1.plot(epoch_list, hist.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, hist.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, epoch_list[-1], 5))
ax1.set_ylabel('Accuracy Value');ax1.set_xlabel('Epoch');ax1.set_title('Accuracy')
ax1.legend(loc="best");ax1.grid(color='gray', linestyle='-', linewidth=0.5)

ax2.plot(epoch_list, hist.history['loss'], label='Train Loss')
ax2.plot(epoch_list, hist.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, epoch_list[-1], 5))
ax2.set_ylabel('Loss Value');ax2.set_xlabel('Epoch');ax2.set_title('Loss')
ax2.legend(loc="best");ax2.grid(color='gray', linestyle='-', linewidth=0.5)

ax3.plot(epoch_list, hist.history['iou_metric'], label='Train IOU metric')
ax3.plot(epoch_list, hist.history['val_iou_metric'], label='Validation IOU metric')
ax3.set_xticks(np.arange(0, epoch_list[-1], 5))
ax3.set_ylabel('IOU metric');ax3.set_xlabel('Epoch');ax3.set_title('IOU metric')
ax3.legend(loc="best");ax3.grid(color='gray', linestyle='-', linewidth=0.5)

# %%
# src: https://www.kaggle.com/aglotero/another-iou-metric
def get_iou_vector(A, B):
    t = A>0
    p = B>0
    intersection = np.logical_and(t,p)
    union = np.logical_or(t,p)
    iou = (np.sum(intersection) + 1e-10 )/ (np.sum(union) + 1e-10)
    return iou
  
def getIOUCurve(mask_org,predicted):
  thresholds = np.linspace(0, 1, 100)
  ious = np.array([get_iou_vector(mask_org, predicted > threshold) for threshold in thresholds])
  thres_best_index = np.argmax(ious[9:-10]) + 9
  iou_best = ious[thres_best_index]
  thres_best = thresholds[thres_best_index]
  return thresholds,ious,iou_best,thres_best

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Unet Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

th, ious, iou_best, th_best = getIOUCurve(Y_v,unet.predict(X_v))
ax1.plot(th, ious,label="For Validation")
ax1.plot(th_best, iou_best, "xr", label="Best threshold")
ax1.set_ylabel('IOU');ax1.set_xlabel('Threshold')
ax1.set_title("Threshold vs IoU ({}, {})".format(th_best, iou_best))

th, ious, iou_best, th_best = getIOUCurve(Y,unet.predict(X))
ax2.plot(th, ious, label="For Training")
ax2.plot(th_best, iou_best, "xr", label="Best threshold")
ax2.set_ylabel('IOU');ax1.set_xlabel('Threshold')
ax2.set_title("Threshold vs IoU ({}, {})".format(th_best, iou_best))
# Out:
# Text(0.5, 1.0, 'Threshold vs IoU (0.494949494949495, 0.8614020703951247)')

# %%
THRESHOLD = 0.2
predicted_mask = (unet.predict(X_v)>THRESHOLD)*1

plt.figure(figsize=(8,30))
i=1;total=10
temp = np.ones_like( Y_v[0] )
for idx in np.random.randint(0,high=X_v.shape[0],size=total):
    plt.subplot(total,3,i);i+=1
    plt.imshow( np.squeeze(X_v[idx],axis=-1), cmap='gray' )
    plt.title("MRI Image");plt.axis('off')
    
    plt.subplot(total,3,i);i+=1
    plt.imshow( np.squeeze(X_v[idx],axis=-1), cmap='gray' )
    plt.imshow( np.squeeze(temp - Y_v[idx],axis=-1), alpha=0.2, cmap='Set1' )
    plt.title("Original Mask");plt.axis('off')
    
    plt.subplot(total,3,i);i+=1
    plt.imshow( np.squeeze(X_v[idx],axis=-1), cmap='gray' )
    plt.imshow( np.squeeze(temp - predicted_mask[idx],axis=-1),  alpha=0.2, cmap='Set1' )
    plt.title("Predicted Mask");plt.axis('off')
